# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabeth-dwenger/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-i3cd8id2
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-i3cd8id2
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=8de9482cb14a10cf5f3cbbf3547e52e403cfe97dbad24ac6124b3e1faf3bc1b1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-96whup6n/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299687, train error 90.47,  test loss 2.301162, test error 91.03
# Epoch   100, train loss 1.949706, train error 74.85,  test loss 1.833757, test error 73.25
# Epoch   200, train loss 1.893439, train error 71.40,  test loss 1.743798, test error 69.57
# Epoch   300, train loss 1.887987, train error 70.80,  test loss 1.729530, test error 68.90
# Epoch   400, train loss 1.888744, train error 70.95,  test loss 1.732840, test error 69.28
# Epoch   500, train loss 1.884509, train error 71.65,  test loss 1.719351, test error 68.80
# Epoch   600, train loss 1.883597, train error 71.00,  test loss 1.720384, test error 68.90
# Epoch   700, train loss 1.885588, train error 70.45,  test loss 1.721124, test error 68.35
# Epoch   800, train loss 1.884985, train error 71.32,  test loss 1.716894, test error 68.78
# Epoch   900, train loss 1.883952, train error 70.62,  test loss 1.721616, test error 69.10
# Training model with   4 hidden variables
# Epoch     0, train loss 2.259345, train error 86.68,  test loss 2.248380, test error 86.22
# Epoch   100, train loss 1.753891, train error 65.05,  test loss 1.590123, test error 61.85
# Epoch   200, train loss 1.738455, train error 63.95,  test loss 1.580757, test error 62.20
# Epoch   300, train loss 1.746331, train error 64.03,  test loss 1.586070, test error 62.20
# Epoch   400, train loss 1.730567, train error 63.83,  test loss 1.571645, test error 61.97
# Epoch   500, train loss 1.742959, train error 64.47,  test loss 1.587202, test error 62.22
# Epoch   600, train loss 1.727648, train error 63.90,  test loss 1.575970, test error 61.35
# Epoch   700, train loss 1.730206, train error 64.10,  test loss 1.573343, test error 61.62
# Epoch   800, train loss 1.724916, train error 63.53,  test loss 1.575744, test error 61.45
# Epoch   900, train loss 1.726058, train error 64.38,  test loss 1.571757, test error 61.53
# Training model with   6 hidden variables
# Epoch     0, train loss 2.239484, train error 84.22,  test loss 2.217396, test error 82.28
# Epoch   100, train loss 1.684757, train error 60.28,  test loss 1.570844, test error 59.38
# Epoch   200, train loss 1.663511, train error 59.45,  test loss 1.561797, test error 58.80
# Epoch   300, train loss 1.656728, train error 59.33,  test loss 1.539926, test error 57.75
# Epoch   400, train loss 1.643147, train error 58.80,  test loss 1.531331, test error 58.50
# Epoch   500, train loss 1.641355, train error 58.35,  test loss 1.535348, test error 57.85
# Epoch   600, train loss 1.638714, train error 58.85,  test loss 1.530508, test error 57.58
# Epoch   700, train loss 1.638023, train error 58.25,  test loss 1.534937, test error 57.20
# Epoch   800, train loss 1.636191, train error 58.08,  test loss 1.523519, test error 57.47
# Epoch   900, train loss 1.636743, train error 58.20,  test loss 1.532586, test error 57.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.249585, train error 83.60,  test loss 2.232256, test error 83.32
# Epoch   100, train loss 1.600909, train error 55.80,  test loss 1.514567, test error 57.33
# Epoch   200, train loss 1.543294, train error 52.95,  test loss 1.435930, test error 54.95
# Epoch   300, train loss 1.523766, train error 52.10,  test loss 1.374738, test error 51.65
# Epoch   400, train loss 1.502236, train error 51.30,  test loss 1.330113, test error 50.33
# Epoch   500, train loss 1.482091, train error 50.38,  test loss 1.310513, test error 49.28
# Epoch   600, train loss 1.465541, train error 49.22,  test loss 1.307833, test error 48.72
# Epoch   700, train loss 1.458152, train error 48.70,  test loss 1.320673, test error 48.60
# Epoch   800, train loss 1.452497, train error 48.38,  test loss 1.330849, test error 49.42
# Epoch   900, train loss 1.447888, train error 48.05,  test loss 1.322369, test error 49.40
# Training model with  10 hidden variables
# Epoch     0, train loss 2.123646, train error 79.47,  test loss 2.076113, test error 78.43
# Epoch   100, train loss 1.574457, train error 54.38,  test loss 1.430654, test error 56.10
# Epoch   200, train loss 1.456415, train error 48.97,  test loss 1.289749, test error 47.17
# Epoch   300, train loss 1.431802, train error 47.95,  test loss 1.276084, test error 47.97
# Epoch   400, train loss 1.421961, train error 48.53,  test loss 1.287411, test error 48.15
# Epoch   500, train loss 1.411548, train error 47.33,  test loss 1.278607, test error 48.30
# Epoch   600, train loss 1.404147, train error 47.30,  test loss 1.283113, test error 47.85
# Epoch   700, train loss 1.401115, train error 47.67,  test loss 1.278674, test error 47.33
# Epoch   800, train loss 1.390589, train error 46.88,  test loss 1.293993, test error 47.62
# Epoch   900, train loss 1.383889, train error 47.08,  test loss 1.300043, test error 47.83
# Training model with  14 hidden variables
# Epoch     0, train loss 2.245669, train error 84.93,  test loss 2.240009, test error 85.72
# Epoch   100, train loss 1.458970, train error 49.55,  test loss 1.371301, test error 50.45
# Epoch   200, train loss 1.352010, train error 45.70,  test loss 1.315748, test error 47.85
# Epoch   300, train loss 1.304736, train error 43.85,  test loss 1.299199, test error 47.03
# Epoch   400, train loss 1.287707, train error 43.28,  test loss 1.352040, test error 48.10
# Epoch   500, train loss 1.260791, train error 42.08,  test loss 1.356192, test error 47.95
# Epoch   600, train loss 1.254115, train error 42.15,  test loss 1.369734, test error 48.05
# Epoch   700, train loss 1.250338, train error 42.15,  test loss 1.401292, test error 48.65
# Epoch   800, train loss 1.244187, train error 41.95,  test loss 1.397867, test error 48.38
# Epoch   900, train loss 1.236992, train error 41.22,  test loss 1.419815, test error 49.30
# Training model with  18 hidden variables
# Epoch     0, train loss 2.196543, train error 82.55,  test loss 2.181812, test error 80.72
# Epoch   100, train loss 1.413166, train error 48.42,  test loss 1.401005, test error 53.67
# Epoch   200, train loss 1.281888, train error 43.95,  test loss 1.382971, test error 51.45
# Epoch   300, train loss 1.239140, train error 42.83,  test loss 1.410447, test error 51.10
# Epoch   400, train loss 1.203929, train error 41.70,  test loss 1.455635, test error 52.10
# Epoch   500, train loss 1.186603, train error 41.45,  test loss 1.464460, test error 51.25
# Epoch   600, train loss 1.167824, train error 41.40,  test loss 1.479130, test error 51.85
# Epoch   700, train loss 1.171743, train error 41.15,  test loss 1.515700, test error 51.55
# Epoch   800, train loss 1.155506, train error 40.58,  test loss 1.531843, test error 51.55
# Epoch   900, train loss 1.160187, train error 41.17,  test loss 1.526047, test error 51.53
# Training model with  22 hidden variables
# Epoch     0, train loss 2.223449, train error 81.72,  test loss 2.204332, test error 81.62
# Epoch   100, train loss 1.259388, train error 42.42,  test loss 1.311291, test error 49.28
# Epoch   200, train loss 1.153680, train error 38.58,  test loss 1.379666, test error 50.42
# Epoch   300, train loss 1.106188, train error 37.30,  test loss 1.437378, test error 51.33
# Epoch   400, train loss 1.072617, train error 36.58,  test loss 1.506760, test error 52.53
# Epoch   500, train loss 1.058546, train error 35.95,  test loss 1.549182, test error 51.92
# Epoch   600, train loss 1.046076, train error 35.30,  test loss 1.580135, test error 53.03
# Epoch   700, train loss 1.045591, train error 36.30,  test loss 1.642619, test error 53.85
# Epoch   800, train loss 1.029263, train error 34.55,  test loss 1.664400, test error 54.15
# Epoch   900, train loss 1.017474, train error 34.20,  test loss 1.651766, test error 53.25
# Training model with  26 hidden variables
# Epoch     0, train loss 2.249809, train error 82.62,  test loss 2.237585, test error 81.22
# Epoch   100, train loss 1.166289, train error 38.95,  test loss 1.313052, test error 49.22
# Epoch   200, train loss 1.026691, train error 34.10,  test loss 1.445294, test error 51.55
# Epoch   300, train loss 0.958521, train error 32.47,  test loss 1.569440, test error 51.78
# Epoch   400, train loss 0.929119, train error 31.82,  test loss 1.673899, test error 51.35
# Epoch   500, train loss 0.905814, train error 30.75,  test loss 1.749201, test error 52.30
# Epoch   600, train loss 0.878647, train error 29.55,  test loss 1.802230, test error 52.38
# Epoch   700, train loss 0.865905, train error 29.47,  test loss 1.875736, test error 53.78
# Epoch   800, train loss 0.860355, train error 30.18,  test loss 1.926319, test error 54.00
# Epoch   900, train loss 0.854577, train error 29.53,  test loss 1.988592, test error 54.15
# Training model with  30 hidden variables
# Epoch     0, train loss 2.188417, train error 80.88,  test loss 2.165933, test error 78.40
# Epoch   100, train loss 1.128595, train error 36.92,  test loss 1.366330, test error 50.10
# Epoch   200, train loss 0.926250, train error 30.82,  test loss 1.545724, test error 51.78
# Epoch   300, train loss 0.836267, train error 28.00,  test loss 1.714955, test error 53.00
# Epoch   400, train loss 0.792527, train error 25.78,  test loss 1.920540, test error 54.38
# Epoch   500, train loss 0.755298, train error 24.78,  test loss 2.095667, test error 54.25
# Epoch   600, train loss 0.714459, train error 22.82,  test loss 2.178349, test error 54.28
# Epoch   700, train loss 0.712532, train error 23.72,  test loss 2.275283, test error 54.00
# Epoch   800, train loss 0.698288, train error 24.22,  test loss 2.458557, test error 55.25
# Epoch   900, train loss 0.672477, train error 22.65,  test loss 2.485953, test error 55.83
# Training model with  35 hidden variables
# Epoch     0, train loss 2.117775, train error 78.93,  test loss 2.083876, test error 77.90
# Epoch   100, train loss 0.995695, train error 32.68,  test loss 1.415716, test error 49.58
# Epoch   200, train loss 0.771185, train error 25.22,  test loss 1.709263, test error 51.08
# Epoch   300, train loss 0.654326, train error 21.57,  test loss 2.068689, test error 52.67
# Epoch   400, train loss 0.601259, train error 20.07,  test loss 2.456910, test error 54.70
# Epoch   500, train loss 0.518550, train error 17.47,  test loss 2.772569, test error 54.28
# Epoch   600, train loss 0.496652, train error 17.43,  test loss 3.178582, test error 55.92
# Epoch   700, train loss 0.463487, train error 16.38,  test loss 3.471105, test error 56.50
# Epoch   800, train loss 0.423361, train error 15.32,  test loss 3.837506, test error 56.15
# Epoch   900, train loss 0.419797, train error 14.65,  test loss 4.173511, test error 57.22
# Training model with  40 hidden variables
# Epoch     0, train loss 2.109022, train error 77.97,  test loss 2.088178, test error 78.22
# Epoch   100, train loss 0.893041, train error 29.47,  test loss 1.462862, test error 49.85
# Epoch   200, train loss 0.631177, train error 20.45,  test loss 1.967065, test error 51.67
# Epoch   300, train loss 0.485057, train error 16.60,  test loss 2.631374, test error 53.45
# Epoch   400, train loss 0.381412, train error 12.78,  test loss 3.325019, test error 55.00
# Epoch   500, train loss 0.314167, train error 10.28,  test loss 4.102258, test error 54.58
# Epoch   600, train loss 0.252296, train error 7.93,  test loss 4.830314, test error 55.88
# Epoch   700, train loss 0.246418, train error 8.28,  test loss 5.590287, test error 56.15
# Epoch   800, train loss 0.228062, train error 7.95,  test loss 6.352424, test error 56.28
# Epoch   900, train loss 0.195370, train error 6.30,  test loss 7.101604, test error 57.20
# Training model with  45 hidden variables
# Epoch     0, train loss 2.135032, train error 79.28,  test loss 2.145704, test error 80.60
# Epoch   100, train loss 0.818652, train error 25.78,  test loss 1.569348, test error 51.20
# Epoch   200, train loss 0.506563, train error 16.30,  test loss 2.326982, test error 53.75
# Epoch   300, train loss 0.420978, train error 15.45,  test loss 3.450905, test error 54.85
# Epoch   400, train loss 0.216293, train error 6.40,  test loss 4.425082, test error 56.25
# Epoch   500, train loss 0.157273, train error 5.00,  test loss 5.808661, test error 57.70
# Epoch   600, train loss 0.063880, train error 1.15,  test loss 6.867627, test error 57.10
# Epoch   700, train loss 0.016312, train error 0.03,  test loss 8.068657, test error 57.60
# Epoch   800, train loss 0.010504, train error 0.00,  test loss 8.828851, test error 57.83
# Epoch   900, train loss 0.007721, train error 0.00,  test loss 9.415343, test error 57.65
# Training model with  50 hidden variables
# Epoch     0, train loss 2.080590, train error 76.90,  test loss 2.030877, test error 77.07
# Epoch   100, train loss 0.727236, train error 22.80,  test loss 1.574841, test error 52.20
# Epoch   200, train loss 0.361650, train error 10.07,  test loss 2.550820, test error 54.45
# Epoch   300, train loss 0.180735, train error 4.50,  test loss 4.003846, test error 56.20
# Epoch   400, train loss 0.065711, train error 0.85,  test loss 5.665089, test error 57.00
# Epoch   500, train loss 0.015930, train error 0.00,  test loss 6.777596, test error 57.70
# Epoch   600, train loss 0.009732, train error 0.00,  test loss 7.458207, test error 57.42
# Epoch   700, train loss 0.006759, train error 0.00,  test loss 7.984397, test error 57.67
# Epoch   800, train loss 0.005154, train error 0.00,  test loss 8.394603, test error 57.75
# Epoch   900, train loss 0.004114, train error 0.00,  test loss 8.725084, test error 57.95
# Training model with  55 hidden variables
# Epoch     0, train loss 2.039930, train error 75.62,  test loss 1.991923, test error 74.65
# Epoch   100, train loss 0.609661, train error 19.62,  test loss 1.753217, test error 52.92
# Epoch   200, train loss 0.191861, train error 4.40,  test loss 3.105414, test error 54.17
# Epoch   300, train loss 0.036632, train error 0.05,  test loss 4.847165, test error 55.72
# Epoch   400, train loss 0.013958, train error 0.00,  test loss 5.900020, test error 56.12
# Epoch   500, train loss 0.008142, train error 0.00,  test loss 6.512751, test error 56.12
# Epoch   600, train loss 0.005571, train error 0.00,  test loss 6.951269, test error 56.33
# Epoch   700, train loss 0.004174, train error 0.00,  test loss 7.299942, test error 56.25
# Epoch   800, train loss 0.003317, train error 0.00,  test loss 7.583009, test error 56.28
# Epoch   900, train loss 0.002724, train error 0.00,  test loss 7.823258, test error 56.30
# Training model with  60 hidden variables
# Epoch     0, train loss 2.111559, train error 79.15,  test loss 2.081356, test error 78.30
# Epoch   100, train loss 0.522336, train error 16.03,  test loss 1.801752, test error 51.75
# Epoch   200, train loss 0.100350, train error 0.85,  test loss 3.452510, test error 53.58
# Epoch   300, train loss 0.019746, train error 0.00,  test loss 4.806525, test error 54.65
# Epoch   400, train loss 0.009451, train error 0.00,  test loss 5.518302, test error 55.00
# Epoch   500, train loss 0.006050, train error 0.00,  test loss 5.979263, test error 55.22
# Epoch   600, train loss 0.004281, train error 0.00,  test loss 6.319380, test error 55.30
# Epoch   700, train loss 0.003288, train error 0.00,  test loss 6.584895, test error 55.42
# Epoch   800, train loss 0.002640, train error 0.00,  test loss 6.810444, test error 55.45
# Epoch   900, train loss 0.002192, train error 0.00,  test loss 7.000638, test error 55.47
# Training model with  70 hidden variables
# Epoch     0, train loss 2.033344, train error 74.53,  test loss 1.985009, test error 74.85
# Epoch   100, train loss 0.378644, train error 9.18,  test loss 2.024566, test error 53.58
# Epoch   200, train loss 0.036046, train error 0.00,  test loss 3.838975, test error 55.45
# Epoch   300, train loss 0.011584, train error 0.00,  test loss 4.754460, test error 55.78
# Epoch   400, train loss 0.006369, train error 0.00,  test loss 5.239530, test error 55.78
# Epoch   500, train loss 0.004285, train error 0.00,  test loss 5.577427, test error 56.00
# Epoch   600, train loss 0.003148, train error 0.00,  test loss 5.835951, test error 55.85
# Epoch   700, train loss 0.002464, train error 0.00,  test loss 6.042909, test error 55.85
# Epoch   800, train loss 0.002012, train error 0.00,  test loss 6.215878, test error 55.85
# Epoch   900, train loss 0.001690, train error 0.00,  test loss 6.363448, test error 55.90
# Training model with  80 hidden variables
# Epoch     0, train loss 2.013795, train error 74.57,  test loss 1.974052, test error 75.68
# Epoch   100, train loss 0.268482, train error 5.30,  test loss 2.092170, test error 52.30
# Epoch   200, train loss 0.021933, train error 0.00,  test loss 3.457462, test error 53.75
# Epoch   300, train loss 0.008298, train error 0.00,  test loss 4.035725, test error 54.10
# Epoch   400, train loss 0.004873, train error 0.00,  test loss 4.383409, test error 54.28
# Epoch   500, train loss 0.003348, train error 0.00,  test loss 4.621113, test error 54.33
# Epoch   600, train loss 0.002511, train error 0.00,  test loss 4.807337, test error 54.35
# Epoch   700, train loss 0.001988, train error 0.00,  test loss 4.959687, test error 54.50
# Epoch   800, train loss 0.001634, train error 0.00,  test loss 5.085665, test error 54.60
# Epoch   900, train loss 0.001381, train error 0.00,  test loss 5.195052, test error 54.42
# Training model with  90 hidden variables
# Epoch     0, train loss 2.032646, train error 74.62,  test loss 1.997879, test error 74.70
# Epoch   100, train loss 0.144893, train error 1.22,  test loss 2.290061, test error 53.10
# Epoch   200, train loss 0.015275, train error 0.00,  test loss 3.429858, test error 52.35
# Epoch   300, train loss 0.006620, train error 0.00,  test loss 3.891606, test error 52.22
# Epoch   400, train loss 0.004050, train error 0.00,  test loss 4.176936, test error 51.92
# Epoch   500, train loss 0.002843, train error 0.00,  test loss 4.384673, test error 52.03
# Epoch   600, train loss 0.002160, train error 0.00,  test loss 4.542729, test error 52.17
# Epoch   700, train loss 0.001727, train error 0.00,  test loss 4.673510, test error 52.17
# Epoch   800, train loss 0.001429, train error 0.00,  test loss 4.784766, test error 52.20
# Epoch   900, train loss 0.001213, train error 0.00,  test loss 4.880800, test error 52.25
# Training model with 100 hidden variables
# Epoch     0, train loss 1.993406, train error 74.15,  test loss 1.929766, test error 74.28
# Epoch   100, train loss 0.108343, train error 0.47,  test loss 2.293568, test error 52.95
# Epoch   200, train loss 0.012770, train error 0.00,  test loss 3.205440, test error 52.65
# Epoch   300, train loss 0.005866, train error 0.00,  test loss 3.599985, test error 52.83
# Epoch   400, train loss 0.003651, train error 0.00,  test loss 3.846576, test error 52.85
# Epoch   500, train loss 0.002592, train error 0.00,  test loss 4.024772, test error 52.92
# Epoch   600, train loss 0.001982, train error 0.00,  test loss 4.163644, test error 52.78
# Epoch   700, train loss 0.001592, train error 0.00,  test loss 4.279316, test error 52.85
# Epoch   800, train loss 0.001321, train error 0.00,  test loss 4.375689, test error 52.92
# Epoch   900, train loss 0.001124, train error 0.00,  test loss 4.459763, test error 52.97
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980896, train error 73.72,  test loss 1.914111, test error 74.47
# Epoch   100, train loss 0.051492, train error 0.00,  test loss 2.278724, test error 51.00
# Epoch   200, train loss 0.009622, train error 0.00,  test loss 2.904201, test error 50.50
# Epoch   300, train loss 0.004759, train error 0.00,  test loss 3.189028, test error 50.42
# Epoch   400, train loss 0.003038, train error 0.00,  test loss 3.370202, test error 50.47
# Epoch   500, train loss 0.002191, train error 0.00,  test loss 3.507365, test error 50.62
# Epoch   600, train loss 0.001693, train error 0.00,  test loss 3.614626, test error 50.58
# Epoch   700, train loss 0.001369, train error 0.00,  test loss 3.703647, test error 50.53
# Epoch   800, train loss 0.001142, train error 0.00,  test loss 3.779308, test error 50.50
# Epoch   900, train loss 0.000976, train error 0.00,  test loss 3.845247, test error 50.58
# Training model with 140 hidden variables
# Epoch     0, train loss 1.978990, train error 73.22,  test loss 1.914216, test error 73.62
# Epoch   100, train loss 0.036833, train error 0.00,  test loss 2.211960, test error 49.15
# Epoch   200, train loss 0.008253, train error 0.00,  test loss 2.711552, test error 49.33
# Epoch   300, train loss 0.004218, train error 0.00,  test loss 2.948473, test error 49.03
# Epoch   400, train loss 0.002740, train error 0.00,  test loss 3.104299, test error 49.08
# Epoch   500, train loss 0.001990, train error 0.00,  test loss 3.222204, test error 48.90
# Epoch   600, train loss 0.001547, train error 0.00,  test loss 3.315042, test error 48.85
# Epoch   700, train loss 0.001255, train error 0.00,  test loss 3.392791, test error 49.00
# Epoch   800, train loss 0.001050, train error 0.00,  test loss 3.458380, test error 49.03
# Epoch   900, train loss 0.000900, train error 0.00,  test loss 3.516134, test error 49.10
# Training model with 160 hidden variables
# Epoch     0, train loss 1.937241, train error 70.60,  test loss 1.869234, test error 72.85
# Epoch   100, train loss 0.028918, train error 0.00,  test loss 2.096799, test error 49.15
# Epoch   200, train loss 0.007248, train error 0.00,  test loss 2.498981, test error 49.00
# Epoch   300, train loss 0.003807, train error 0.00,  test loss 2.696803, test error 48.83
# Epoch   400, train loss 0.002504, train error 0.00,  test loss 2.828498, test error 48.92
# Epoch   500, train loss 0.001835, train error 0.00,  test loss 2.925117, test error 48.90
# Epoch   600, train loss 0.001432, train error 0.00,  test loss 3.004773, test error 48.83
# Epoch   700, train loss 0.001167, train error 0.00,  test loss 3.069252, test error 48.80
# Epoch   800, train loss 0.000979, train error 0.00,  test loss 3.125579, test error 48.78
# Epoch   900, train loss 0.000840, train error 0.00,  test loss 3.174265, test error 48.80
# Training model with 180 hidden variables
# Epoch     0, train loss 1.920768, train error 70.10,  test loss 1.850590, test error 71.57
# Epoch   100, train loss 0.024982, train error 0.00,  test loss 2.029872, test error 49.25
# Epoch   200, train loss 0.006666, train error 0.00,  test loss 2.379028, test error 49.10
# Epoch   300, train loss 0.003558, train error 0.00,  test loss 2.553753, test error 49.08
# Epoch   400, train loss 0.002357, train error 0.00,  test loss 2.672979, test error 49.05
# Epoch   500, train loss 0.001733, train error 0.00,  test loss 2.760764, test error 49.00
# Epoch   600, train loss 0.001357, train error 0.00,  test loss 2.831406, test error 49.08
# Epoch   700, train loss 0.001106, train error 0.00,  test loss 2.891131, test error 49.05
# Epoch   800, train loss 0.000930, train error 0.00,  test loss 2.941710, test error 49.05
# Epoch   900, train loss 0.000799, train error 0.00,  test loss 2.986121, test error 49.08
# Training model with 200 hidden variables
# Epoch     0, train loss 1.939869, train error 72.40,  test loss 1.881101, test error 73.80
# Epoch   100, train loss 0.021145, train error 0.00,  test loss 1.970879, test error 47.83
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.279262, test error 47.80
# Epoch   300, train loss 0.003308, train error 0.00,  test loss 2.438527, test error 48.17
# Epoch   400, train loss 0.002208, train error 0.00,  test loss 2.545330, test error 48.05
# Epoch   500, train loss 0.001632, train error 0.00,  test loss 2.626979, test error 47.95
# Epoch   600, train loss 0.001282, train error 0.00,  test loss 2.691590, test error 48.00
# Epoch   700, train loss 0.001049, train error 0.00,  test loss 2.745672, test error 47.88
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.791946, test error 47.92
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.832565, test error 47.90
# Training model with 250 hidden variables
# Epoch     0, train loss 1.892772, train error 68.62,  test loss 1.835267, test error 71.38
# Epoch   100, train loss 0.016995, train error 0.00,  test loss 1.898548, test error 46.60
# Epoch   200, train loss 0.005327, train error 0.00,  test loss 2.150877, test error 46.33
# Epoch   300, train loss 0.002968, train error 0.00,  test loss 2.284448, test error 46.45
# Epoch   400, train loss 0.002003, train error 0.00,  test loss 2.374609, test error 46.22
# Epoch   500, train loss 0.001490, train error 0.00,  test loss 2.441950, test error 46.30
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.497305, test error 46.40
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.542891, test error 46.28
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.582257, test error 46.25
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.616464, test error 46.28
# Training model with 300 hidden variables
# Epoch     0, train loss 1.866153, train error 67.65,  test loss 1.788563, test error 71.15
# Epoch   100, train loss 0.014264, train error 0.00,  test loss 1.877909, test error 47.47
# Epoch   200, train loss 0.004784, train error 0.00,  test loss 2.100201, test error 47.33
# Epoch   300, train loss 0.002707, train error 0.00,  test loss 2.220359, test error 47.20
# Epoch   400, train loss 0.001845, train error 0.00,  test loss 2.303089, test error 47.03
# Epoch   500, train loss 0.001381, train error 0.00,  test loss 2.367105, test error 46.95
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.418475, test error 46.97
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.461140, test error 46.88
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.498110, test error 46.83
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.530390, test error 46.78
# Training model with 400 hidden variables
# Epoch     0, train loss 1.923059, train error 70.00,  test loss 1.881485, test error 73.60
# Epoch   100, train loss 0.011587, train error 0.00,  test loss 1.693793, test error 44.40
# Epoch   200, train loss 0.004133, train error 0.00,  test loss 1.861098, test error 44.30
# Epoch   300, train loss 0.002395, train error 0.00,  test loss 1.955749, test error 44.17
# Epoch   400, train loss 0.001652, train error 0.00,  test loss 2.020494, test error 44.05
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.071239, test error 44.10
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.111753, test error 44.08
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.145613, test error 44.08
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.175097, test error 44.03
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.201025, test error 44.03

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
