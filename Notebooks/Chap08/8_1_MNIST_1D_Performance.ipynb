# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabeth-dwenger/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-e_u49ndi
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-e_u49ndi
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=9fbbe0235bfae0d98c7b35f25f787e4ca86ea4825275aa1bdd78982880b7766c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hjw379az/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
import torch

D_i = 40    # Input dimensions
D_k = 500   # Hidden dimensions
D_o = 10    # Output dimensions

# Define the model: 2 hidden layers with ReLU
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)

# Define He initialization for linear layers
def weights_init(layer_in):
    if isinstance(layer_in, torch.nn.Linear):
        torch.nn.init.kaiming_normal_(layer_in.weight, nonlinearity='relu')
        if layer_in.bias is not None:
            torch.nn.init.zeros_(layer_in.bias)

# Apply the initialization
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=500, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.414288, train error 53.28,  test loss 1.572446, test error 62.00
# Epoch     1, train loss 1.084602, train error 37.88,  test loss 1.385095, test error 53.90
# Epoch     2, train loss 0.839618, train error 29.25,  test loss 1.250780, test error 47.50
# Epoch     3, train loss 0.670114, train error 22.30,  test loss 1.163232, test error 43.10
# Epoch     4, train loss 0.510342, train error 15.85,  test loss 1.211121, test error 45.30
# Epoch     5, train loss 0.349239, train error 9.12,  test loss 1.096254, test error 41.50
# Epoch     6, train loss 0.262532, train error 5.78,  test loss 1.040046, test error 38.10
# Epoch     7, train loss 0.195774, train error 3.90,  test loss 1.077255, test error 36.90
# Epoch     8, train loss 0.125147, train error 1.95,  test loss 1.072143, test error 36.50
# Epoch     9, train loss 0.072098, train error 0.40,  test loss 1.110689, test error 36.30
# Epoch    10, train loss 0.045666, train error 0.00,  test loss 1.050061, test error 35.50
# Epoch    11, train loss 0.036730, train error 0.00,  test loss 1.073982, test error 34.50
# Epoch    12, train loss 0.031470, train error 0.00,  test loss 1.088247, test error 35.20
# Epoch    13, train loss 0.027999, train error 0.00,  test loss 1.103029, test error 35.80
# Epoch    14, train loss 0.025754, train error 0.00,  test loss 1.110039, test error 35.10
# Epoch    15, train loss 0.022513, train error 0.00,  test loss 1.124717, test error 34.80
# Epoch    16, train loss 0.020576, train error 0.00,  test loss 1.129123, test error 35.30
# Epoch    17, train loss 0.018934, train error 0.00,  test loss 1.130954, test error 35.70
# Epoch    18, train loss 0.017686, train error 0.00,  test loss 1.144418, test error 35.10
# Epoch    19, train loss 0.016150, train error 0.00,  test loss 1.153559, test error 34.70
# Epoch    20, train loss 0.015562, train error 0.00,  test loss 1.155130, test error 34.90
# Epoch    21, train loss 0.015037, train error 0.00,  test loss 1.160020, test error 34.90
# Epoch    22, train loss 0.014586, train error 0.00,  test loss 1.159443, test error 34.70
# Epoch    23, train loss 0.014129, train error 0.00,  test loss 1.164787, test error 34.80
# Epoch    24, train loss 0.013720, train error 0.00,  test loss 1.168512, test error 34.90
# Epoch    25, train loss 0.013338, train error 0.00,  test loss 1.170932, test error 35.00
# Epoch    26, train loss 0.012951, train error 0.00,  test loss 1.172865, test error 35.10
# Epoch    27, train loss 0.012629, train error 0.00,  test loss 1.177470, test error 34.80
# Epoch    28, train loss 0.012297, train error 0.00,  test loss 1.179814, test error 35.00
# Epoch    29, train loss 0.011983, train error 0.00,  test loss 1.181682, test error 34.70
# Epoch    30, train loss 0.011783, train error 0.00,  test loss 1.185395, test error 34.80
# Epoch    31, train loss 0.011634, train error 0.00,  test loss 1.186759, test error 34.60
# Epoch    32, train loss 0.011489, train error 0.00,  test loss 1.187369, test error 34.60
# Epoch    33, train loss 0.011352, train error 0.00,  test loss 1.189833, test error 34.50
# Epoch    34, train loss 0.011210, train error 0.00,  test loss 1.191202, test error 34.80
# Epoch    35, train loss 0.011076, train error 0.00,  test loss 1.191188, test error 34.50
# Epoch    36, train loss 0.010942, train error 0.00,  test loss 1.193688, test error 34.80
# Epoch    37, train loss 0.010813, train error 0.00,  test loss 1.194771, test error 34.60
# Epoch    38, train loss 0.010688, train error 0.00,  test loss 1.196110, test error 34.70
# Epoch    39, train loss 0.010565, train error 0.00,  test loss 1.197976, test error 34.80
# Epoch    40, train loss 0.010501, train error 0.00,  test loss 1.198567, test error 34.70
# Epoch    41, train loss 0.010439, train error 0.00,  test loss 1.198508, test error 34.80
# Epoch    42, train loss 0.010380, train error 0.00,  test loss 1.199363, test error 34.80
# Epoch    43, train loss 0.010322, train error 0.00,  test loss 1.200002, test error 34.60
# Epoch    44, train loss 0.010264, train error 0.00,  test loss 1.201606, test error 34.60
# Epoch    45, train loss 0.010206, train error 0.00,  test loss 1.201601, test error 34.70
# Epoch    46, train loss 0.010150, train error 0.00,  test loss 1.202516, test error 34.60
# Epoch    47, train loss 0.010093, train error 0.00,  test loss 1.202655, test error 34.60
# Epoch    48, train loss 0.010038, train error 0.00,  test loss 1.203852, test error 34.70
# Epoch    49, train loss 0.009984, train error 0.00,  test loss 1.203879, test error 34.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
