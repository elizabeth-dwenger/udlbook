# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabeth-dwenger/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-a73xbexc
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-a73xbexc
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=f857d6ee220fb0d7fabe61e46d6dcb1e0d3051ea3d3b2d18f3545574edb1e453
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jy5hdiyw/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)               # First linear layer
    h2 = self.linear2(h1.relu())       # First residual block
    h2 = h1 + h2                       # Add residual connection

    h3 = self.linear3(h2.relu())       # Second residual block
    h3 = h2 + h3                       # Add residual connection

    out = self.linear4(h3)             # Final linear layer to output
    return out

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.727627, train error 62.10,  val loss 1.845441, percent error 65.40
# Epoch     1, train loss 1.115833, train error 42.33,  val loss 1.275209, percent error 48.60
# Epoch     2, train loss 1.000143, train error 38.30,  val loss 1.252365, percent error 49.20
# Epoch     3, train loss 0.905731, train error 33.72,  val loss 1.197312, percent error 46.10
# Epoch     4, train loss 0.824191, train error 31.25,  val loss 1.158391, percent error 44.00
# Epoch     5, train loss 0.732307, train error 27.82,  val loss 1.104797, percent error 39.50
# Epoch     6, train loss 0.733464, train error 27.88,  val loss 1.180432, percent error 41.90
# Epoch     7, train loss 0.642473, train error 23.55,  val loss 1.127104, percent error 40.00
# Epoch     8, train loss 0.622472, train error 23.78,  val loss 1.148083, percent error 38.90
# Epoch     9, train loss 0.519041, train error 20.30,  val loss 1.148968, percent error 39.50
# Epoch    10, train loss 0.466755, train error 17.47,  val loss 1.184110, percent error 38.30
# Epoch    11, train loss 0.437399, train error 16.72,  val loss 1.244334, percent error 37.90
# Epoch    12, train loss 0.400815, train error 14.82,  val loss 1.208463, percent error 38.40
# Epoch    13, train loss 0.396629, train error 14.45,  val loss 1.355801, percent error 38.80
# Epoch    14, train loss 0.387037, train error 14.25,  val loss 1.449228, percent error 39.00
# Epoch    15, train loss 0.341079, train error 12.82,  val loss 1.294347, percent error 36.80
# Epoch    16, train loss 0.301113, train error 11.10,  val loss 1.340350, percent error 35.40
# Epoch    17, train loss 0.348879, train error 12.30,  val loss 1.536467, percent error 39.30
# Epoch    18, train loss 0.362259, train error 13.15,  val loss 1.505389, percent error 35.30
# Epoch    19, train loss 0.338443, train error 11.57,  val loss 1.478744, percent error 36.40
# Epoch    20, train loss 0.093391, train error 2.28,  val loss 1.239922, percent error 31.00
# Epoch    21, train loss 0.047582, train error 0.68,  val loss 1.253870, percent error 30.60
# Epoch    22, train loss 0.027815, train error 0.18,  val loss 1.277837, percent error 31.20
# Epoch    23, train loss 0.019679, train error 0.05,  val loss 1.302807, percent error 30.10
# Epoch    24, train loss 0.015511, train error 0.03,  val loss 1.340571, percent error 29.60
# Epoch    25, train loss 0.012664, train error 0.00,  val loss 1.358076, percent error 30.20
# Epoch    26, train loss 0.010815, train error 0.00,  val loss 1.396982, percent error 30.40
# Epoch    27, train loss 0.009360, train error 0.00,  val loss 1.411867, percent error 30.20
# Epoch    28, train loss 0.008293, train error 0.00,  val loss 1.437893, percent error 30.40
# Epoch    29, train loss 0.007646, train error 0.00,  val loss 1.454821, percent error 30.20
# Epoch    30, train loss 0.006784, train error 0.00,  val loss 1.475048, percent error 30.90
# Epoch    31, train loss 0.006165, train error 0.00,  val loss 1.491241, percent error 30.90
# Epoch    32, train loss 0.005689, train error 0.00,  val loss 1.508596, percent error 30.60
# Epoch    33, train loss 0.005277, train error 0.00,  val loss 1.524226, percent error 30.60
# Epoch    34, train loss 0.004914, train error 0.00,  val loss 1.538198, percent error 30.90
# Epoch    35, train loss 0.004645, train error 0.00,  val loss 1.551696, percent error 30.70
# Epoch    36, train loss 0.004328, train error 0.00,  val loss 1.562905, percent error 30.90
# Epoch    37, train loss 0.004073, train error 0.00,  val loss 1.576632, percent error 30.40
# Epoch    38, train loss 0.003854, train error 0.00,  val loss 1.589937, percent error 30.30
# Epoch    39, train loss 0.003649, train error 0.00,  val loss 1.599505, percent error 30.40
# Epoch    40, train loss 0.003550, train error 0.00,  val loss 1.605438, percent error 30.50
# Epoch    41, train loss 0.003462, train error 0.00,  val loss 1.610766, percent error 30.50
# Epoch    42, train loss 0.003379, train error 0.00,  val loss 1.615892, percent error 30.50
# Epoch    43, train loss 0.003302, train error 0.00,  val loss 1.620527, percent error 30.50
# Epoch    44, train loss 0.003226, train error 0.00,  val loss 1.625823, percent error 30.60
# Epoch    45, train loss 0.003155, train error 0.00,  val loss 1.629577, percent error 30.60
# Epoch    46, train loss 0.003085, train error 0.00,  val loss 1.634729, percent error 30.50
# Epoch    47, train loss 0.003020, train error 0.00,  val loss 1.639427, percent error 30.70
# Epoch    48, train loss 0.002957, train error 0.00,  val loss 1.645532, percent error 30.60
# Epoch    49, train loss 0.002895, train error 0.00,  val loss 1.648414, percent error 30.80
# Epoch    50, train loss 0.002837, train error 0.00,  val loss 1.652737, percent error 30.80
# Epoch    51, train loss 0.002781, train error 0.00,  val loss 1.656655, percent error 30.90
# Epoch    52, train loss 0.002726, train error 0.00,  val loss 1.662148, percent error 30.90
# Epoch    53, train loss 0.002673, train error 0.00,  val loss 1.666088, percent error 30.80
# Epoch    54, train loss 0.002623, train error 0.00,  val loss 1.669087, percent error 30.90
# Epoch    55, train loss 0.002575, train error 0.00,  val loss 1.674327, percent error 30.80
# Epoch    56, train loss 0.002526, train error 0.00,  val loss 1.678062, percent error 30.80
# Epoch    57, train loss 0.002480, train error 0.00,  val loss 1.682127, percent error 30.60
# Epoch    58, train loss 0.002437, train error 0.00,  val loss 1.686257, percent error 30.70
# Epoch    59, train loss 0.002394, train error 0.00,  val loss 1.689846, percent error 30.70
# Epoch    60, train loss 0.002373, train error 0.00,  val loss 1.692226, percent error 30.80
# Epoch    61, train loss 0.002352, train error 0.00,  val loss 1.693069, percent error 30.80
# Epoch    62, train loss 0.002332, train error 0.00,  val loss 1.695214, percent error 30.80
# Epoch    63, train loss 0.002312, train error 0.00,  val loss 1.697470, percent error 30.80
# Epoch    64, train loss 0.002293, train error 0.00,  val loss 1.699157, percent error 30.80
# Epoch    65, train loss 0.002274, train error 0.00,  val loss 1.700881, percent error 30.80
# Epoch    66, train loss 0.002255, train error 0.00,  val loss 1.702750, percent error 30.80
# Epoch    67, train loss 0.002237, train error 0.00,  val loss 1.704470, percent error 30.90
# Epoch    68, train loss 0.002219, train error 0.00,  val loss 1.706080, percent error 30.80
# Epoch    69, train loss 0.002201, train error 0.00,  val loss 1.708134, percent error 30.90
# Epoch    70, train loss 0.002183, train error 0.00,  val loss 1.710086, percent error 30.90
# Epoch    71, train loss 0.002166, train error 0.00,  val loss 1.711971, percent error 30.90
# Epoch    72, train loss 0.002149, train error 0.00,  val loss 1.713287, percent error 30.90
# Epoch    73, train loss 0.002132, train error 0.00,  val loss 1.714559, percent error 30.90
# Epoch    74, train loss 0.002115, train error 0.00,  val loss 1.716687, percent error 30.90
# Epoch    75, train loss 0.002099, train error 0.00,  val loss 1.718102, percent error 31.00
# Epoch    76, train loss 0.002083, train error 0.00,  val loss 1.720383, percent error 30.90
# Epoch    77, train loss 0.002067, train error 0.00,  val loss 1.721333, percent error 30.80
# Epoch    78, train loss 0.002051, train error 0.00,  val loss 1.723093, percent error 31.00
# Epoch    79, train loss 0.002036, train error 0.00,  val loss 1.725193, percent error 30.90
# Epoch    80, train loss 0.002028, train error 0.00,  val loss 1.725896, percent error 30.90
# Epoch    81, train loss 0.002020, train error 0.00,  val loss 1.726689, percent error 30.80
# Epoch    82, train loss 0.002013, train error 0.00,  val loss 1.727451, percent error 30.90
# Epoch    83, train loss 0.002005, train error 0.00,  val loss 1.728204, percent error 30.90
# Epoch    84, train loss 0.001998, train error 0.00,  val loss 1.729139, percent error 30.90
# Epoch    85, train loss 0.001991, train error 0.00,  val loss 1.729826, percent error 30.90
# Epoch    86, train loss 0.001983, train error 0.00,  val loss 1.730722, percent error 30.80
# Epoch    87, train loss 0.001976, train error 0.00,  val loss 1.731425, percent error 30.90
# Epoch    88, train loss 0.001969, train error 0.00,  val loss 1.732138, percent error 30.90
# Epoch    89, train loss 0.001962, train error 0.00,  val loss 1.733206, percent error 30.90
# Epoch    90, train loss 0.001955, train error 0.00,  val loss 1.733962, percent error 31.00
# Epoch    91, train loss 0.001948, train error 0.00,  val loss 1.734583, percent error 30.90
# Epoch    92, train loss 0.001940, train error 0.00,  val loss 1.735353, percent error 30.90
# Epoch    93, train loss 0.001934, train error 0.00,  val loss 1.736194, percent error 31.00
# Epoch    94, train loss 0.001927, train error 0.00,  val loss 1.737088, percent error 31.00
# Epoch    95, train loss 0.001920, train error 0.00,  val loss 1.737674, percent error 30.90
# Epoch    96, train loss 0.001913, train error 0.00,  val loss 1.738667, percent error 31.00
# Epoch    97, train loss 0.001906, train error 0.00,  val loss 1.739207, percent error 30.90
# Epoch    98, train loss 0.001899, train error 0.00,  val loss 1.740082, percent error 31.00
# Epoch    99, train loss 0.001893, train error 0.00,  val loss 1.740923, percent error 31.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
