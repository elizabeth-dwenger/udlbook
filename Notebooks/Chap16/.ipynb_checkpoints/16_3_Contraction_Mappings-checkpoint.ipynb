# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap16/16_3_Contraction_Mappings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 16.3: Contraction mappings**
#
# This notebook investigates a 1D normalizing flows example similar to that illustrated in figure 16.9 in the book.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define a function that is a contraction mapping
def f(z):
    return 0.3 + 0.5 *z + 0.02 * np.sin(z*15)

# %%
def draw_function(f, fixed_point=None):
  z = np.arange(0,1,0.01)
  z_prime = f(z)

  # Draw this function
  fig, ax = plt.subplots()
  ax.plot(z, z_prime,'c-')
  ax.plot([0,1],[0,1],'k--')
  if fixed_point!=None:
    ax.plot(fixed_point, fixed_point, 'ro')
  ax.set_xlim(0,1)
  ax.set_ylim(0,1)
  ax.set_xlabel('Input, $z$')
  ax.set_ylabel('Output, f$[z]$')
  plt.show()

# %%
draw_function(f)

# %% [markdown]
# Now let's find where $\text{f}[z]=z$ using fixed point iteration

# %%
# Takes a function f and a starting point z
def fixed_point_iteration(f, z0, max_iter=20, tol=1e-6):
  # TODO -- write this function
  # Print out the iterations as you go, so you can see the progress
  # Set the maximum number of iterations to 20
  # Replace this line
    z = z0
    print(f"Starting fixed point iteration with z0 = {z0:.6f}")
    print(f"Iteration 0: z = {z:.6f}")
    
    for i in range(1, max_iter + 1):
        z_new = f(z)
        error = abs(z_new - z)
        
        print(f"Iteration {i}: z = {z_new:.6f}, error = {error:.2e}")
        
        # Check for convergence
        if error < tol:
            print(f"Converged after {i} iterations!")
            return z_new, True
        
        z = z_new
    
    print(f"Did not converge after {max_iter} iterations. Final error: {error:.2e}")
    return z, False

# %% [markdown]
# Now let's test that and plot the solution

# %%
# Now let's test that
z = fixed_point_iteration(f, 0.2)
draw_function(f, z)
# Out:
# Starting fixed point iteration with z0 = 0.200000
# Iteration 0: z = 0.200000
# Iteration 1: z = 0.402822, error = 2.03e-01
# Iteration 2: z = 0.496641, error = 9.38e-02
# Iteration 3: z = 0.566707, error = 7.01e-02
# Iteration 4: z = 0.599316, error = 3.26e-02
# Iteration 5: z = 0.608087, error = 8.77e-03
# Iteration 6: z = 0.610020, error = 1.93e-03
# Iteration 7: z = 0.610431, error = 4.11e-04
# Iteration 8: z = 0.610518, error = 8.67e-05
# Iteration 9: z = 0.610536, error = 1.83e-05
# Iteration 10: z = 0.610540, error = 3.85e-06
# Iteration 11: z = 0.610541, error = 8.10e-07
# Converged after 11 iterations!

# %%
# Let's define another function
def f2(z):
    return 0.7 + -0.6 *z + 0.03 * np.sin(z*15)
draw_function(f2)

# %%
# Now let's test that
# TODO Before running this code, predict what you think will happen
z = fixed_point_iteration(f2, 0.9)
draw_function(f2, z)
# Out:
# Iteration  1 | z = 0.184114 | f(z) = 0.600656
# Iteration  2 | z = 0.600656 | f(z) = 0.351700
# Iteration  3 | z = 0.351700 | f(z) = 0.463612
# Iteration  4 | z = 0.463612 | f(z) = 0.440486
# Iteration  5 | z = 0.440486 | f(z) = 0.445262
# Iteration  6 | z = 0.445262 | f(z) = 0.444408
# Iteration  7 | z = 0.444408 | f(z) = 0.444565
# Iteration  8 | z = 0.444565 | f(z) = 0.444536
# Iteration  9 | z = 0.444536 | f(z) = 0.444541
# Iteration 10 | z = 0.444541 | f(z) = 0.444540
# Iteration 11 | z = 0.444540 | f(z) = 0.444540
# Converged.

# %%
# Let's define another function
# Define a function that is a contraction mapping
def f3(z):
    return -0.2 + 1.5 *z + 0.1 * np.sin(z*15)
draw_function(f3)

# %%
# Now let's test that
# TODO Before running this code, predict what you think will happen
z = fixed_point_iteration(f3, 0.7)
draw_function(f3, z)
# Out:
# Starting fixed point iteration with z0 = 0.700000
# Iteration 0: z = 0.700000
# Iteration 1: z = 0.762030, error = 6.20e-02
# Iteration 2: z = 0.852354, error = 9.03e-02
# Iteration 3: z = 1.100249, error = 2.48e-01
# Iteration 4: z = 1.378933, error = 2.79e-01
# Iteration 5: z = 1.964945, error = 5.86e-01
# Iteration 6: z = 2.654219, error = 6.89e-01
# Iteration 7: z = 3.866925, error = 1.21e+00
# Iteration 8: z = 5.699721, error = 1.83e+00
# Iteration 9: z = 8.287262, error = 2.59e+00
# Iteration 10: z = 12.133218, error = 3.85e+00
# Iteration 11: z = 17.978580, error = 5.85e+00
# Iteration 12: z = 26.720079, error = 8.74e+00
# Iteration 13: z = 39.783182, error = 1.31e+01
# Iteration 14: z = 59.459347, error = 1.97e+01
# Iteration 15: z = 88.957364, error = 2.95e+01
# Iteration 16: z = 133.308916, error = 4.44e+01
# Iteration 17: z = 199.863369, error = 6.66e+01
# Iteration 18: z = 299.671559, error = 9.98e+01
# Iteration 19: z = 449.359240, error = 1.50e+02
# Iteration 20: z = 673.739376, error = 2.24e+02
# Did not converge after 20 iterations. Final error: 2.24e+02

# %% [markdown]
# Finally, let's invert a problem of the form $y = z+ f[z]$  for a given value of $y$. What is the $z$ that maps to it?

# %%
def f4(z):
   return -0.3 + 0.5 *z + 0.02 * np.sin(z*15)

# %%
def fixed_point_iteration_z_plus_f(f, y, z0, max_iter=20, tol=1e-6):
  # TODO -- write this function
  # Replace this line
    def g(z):
        return y - f(z)
    
    z = z0
    print(f"Solving z + f(z) = {y:.6f} starting with z0 = {z0:.6f}")
    print(f"Iteration 0: z = {z:.6f}, z + f(z) = {z + f(z):.6f}")
    
    for i in range(1, max_iter + 1):
        z_new = g(z)
        equation_value = z_new + f(z_new)
        error = abs(z_new - z)
        equation_error = abs(equation_value - y)
        
        print(f"Iteration {i}: z = {z_new:.6f}, z + f(z) = {equation_value:.6f}, error = {error:.2e}")
        
        # Check for convergence based on change in z
        if error < tol:
            print(f"Converged after {i} iterations!")
            print(f"Final equation error |z + f(z) - y| = {equation_error:.2e}")
            return z_new
        
        z = z_new
    
    print(f"Did not converge after {max_iter} iterations.")
    print(f"Final equation error |z + f(z) - y| = {abs(z + f(z) - y):.2e}")
    return z

# %%
def draw_function2(f, y, fixed_point=None):
  z = np.arange(0,1,0.01)
  z_prime = z+f(z)

  # Draw this function
  fig, ax = plt.subplots()
  ax.plot(z, z_prime,'c-')
  ax.plot(z, y-f(z),'r-')
  ax.plot([0,1],[0,1],'k--')
  if fixed_point!=None:
    ax.plot(fixed_point, y, 'ro')
  ax.set_xlim(0,1)
  ax.set_ylim(0,1)
  ax.set_xlabel('Input, $z$')
  ax.set_ylabel('Output, z+f$[z]$')
  plt.show()

# %%
# Test this out and draw
y = 0.8
z = fixed_point_iteration_z_plus_f(f4,y,0.2)
draw_function2(f4,y,z)
# If you have done this correctly, the red dot should be
# where the cyan curve has a y value of 0.8
# Out:
# Solving z + f(z) = 0.800000 starting with z0 = 0.200000
# Iteration 0: z = 0.200000, z + f(z) = 0.002822
# Iteration 1: z = 0.997178, z + f(z) = 1.209404, error = 7.97e-01
# Iteration 2: z = 0.587774, z + f(z) = 0.593088, error = 4.09e-01
# Iteration 3: z = 0.794686, z + f(z) = 0.879987, error = 2.07e-01
# Iteration 4: z = 0.714698, z + f(z) = 0.752800, error = 8.00e-02
# Iteration 5: z = 0.761899, z + f(z) = 0.824693, error = 4.72e-02
# Iteration 6: z = 0.737206, z + f(z) = 0.785848, error = 2.47e-02
# Iteration 7: z = 0.751358, z + f(z) = 0.807788, error = 1.42e-02
# Iteration 8: z = 0.743571, z + f(z) = 0.795605, error = 7.79e-03
# Iteration 9: z = 0.747966, z + f(z) = 0.802448, error = 4.40e-03
# Iteration 10: z = 0.745518, z + f(z) = 0.798626, error = 2.45e-03
# Iteration 11: z = 0.746892, z + f(z) = 0.800768, error = 1.37e-03
# Iteration 12: z = 0.746124, z + f(z) = 0.799570, error = 7.68e-04
# Iteration 13: z = 0.746554, z + f(z) = 0.800241, error = 4.30e-04
# Iteration 14: z = 0.746313, z + f(z) = 0.799865, error = 2.41e-04
# Iteration 15: z = 0.746448, z + f(z) = 0.800075, error = 1.35e-04
# Iteration 16: z = 0.746373, z + f(z) = 0.799958, error = 7.54e-05
# Iteration 17: z = 0.746415, z + f(z) = 0.800024, error = 4.22e-05
# Iteration 18: z = 0.746391, z + f(z) = 0.799987, error = 2.36e-05
# Iteration 19: z = 0.746405, z + f(z) = 0.800007, error = 1.32e-05
# Iteration 20: z = 0.746397, z + f(z) = 0.799996, error = 7.40e-06
# Did not converge after 20 iterations.
# Final equation error |z + f(z) - y| = 4.14e-06
